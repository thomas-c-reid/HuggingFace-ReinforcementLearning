# %%
# INSTALL DEPENDENCIES
# !apt install swig cmake
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt

# To View virtual screen
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gymnasium as gym

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
env = gym.make('LunarLander-v2')

model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda=0.98,
    ent_coef = 0.01,
    verbose=1
)

model.learn(total_timesteps=1000000)
model_name = 'ppo-LunarLander-v2'
model.save(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
# |    value_loss           | 14.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 463          |
# |    ep_rew_mean          | 202          |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 740          |
# |    time_elapsed         | 1336         |
# |    total_timesteps      | 757760       |
# | train/                  |              |
# |    approx_kl            | 0.0018198858 |
# |    clip_fraction        | 0.00366      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 396          |
# |    n_updates            | 2956         |
# |    policy_gradient_loss | -0.000319    |
# |    value_loss           | 1.12e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 466           |
# |    ep_rew_mean          | 198           |
# | time/                   |               |
# |    fps                  | 567           |
# |    iterations           | 741           |
# |    time_elapsed         | 1338          |
# |    total_timesteps      | 758784        |
# | train/                  |               |
# |    approx_kl            | 0.00067194726 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.764        |
# |    explained_variance   | 0.93          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.92          |
# |    n_updates            | 2960          |
# |    policy_gradient_loss | -0.000479     |
# |    value_loss           | 45.8          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 468           |
# |    ep_rew_mean          | 202           |
# | time/                   |               |
# |    fps                  | 566           |
# |    iterations           | 742           |
# |    time_elapsed         | 1340          |
# |    total_timesteps      | 759808        |
# | train/                  |               |
# |    approx_kl            | 0.00021204248 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.622        |
# |    explained_variance   | 0.339         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 27.7          |
# |    n_updates            | 2964          |
# |    policy_gradient_loss | -0.000397     |
# |    value_loss           | 903           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 467         |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 743         |
# |    time_elapsed         | 1342        |
# |    total_timesteps      | 760832      |
# | train/                  |             |
# |    approx_kl            | 0.006956022 |
# |    clip_fraction        | 0.0249      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.11        |
# |    n_updates            | 2968        |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 27.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 467         |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 744         |
# |    time_elapsed         | 1343        |
# |    total_timesteps      | 761856      |
# | train/                  |             |
# |    approx_kl            | 0.005363153 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86        |
# |    n_updates            | 2972        |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 21.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 468          |
# |    ep_rew_mean          | 205          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 745          |
# |    time_elapsed         | 1345         |
# |    total_timesteps      | 762880       |
# | train/                  |              |
# |    approx_kl            | 0.0040744226 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.13         |
# |    n_updates            | 2976         |
# |    policy_gradient_loss | -0.00652     |
# |    value_loss           | 16.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 467          |
# |    ep_rew_mean          | 206          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 746          |
# |    time_elapsed         | 1347         |
# |    total_timesteps      | 763904       |
# | train/                  |              |
# |    approx_kl            | 0.0052685402 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43         |
# |    n_updates            | 2980         |
# |    policy_gradient_loss | -0.000263    |
# |    value_loss           | 9.53         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 467         |
# |    ep_rew_mean          | 206         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 747         |
# |    time_elapsed         | 1348        |
# |    total_timesteps      | 764928      |
# | train/                  |             |
# |    approx_kl            | 0.005826354 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.69        |
# |    n_updates            | 2984        |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 18.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 467          |
# |    ep_rew_mean          | 207          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 748          |
# |    time_elapsed         | 1350         |
# |    total_timesteps      | 765952       |
# | train/                  |              |
# |    approx_kl            | 0.0045963405 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.801       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.29         |
# |    n_updates            | 2988         |
# |    policy_gradient_loss | -0.00612     |
# |    value_loss           | 11.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | 208         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 749         |
# |    time_elapsed         | 1352        |
# |    total_timesteps      | 766976      |
# | train/                  |             |
# |    approx_kl            | 0.003543986 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.32        |
# |    n_updates            | 2992        |
# |    policy_gradient_loss | -0.000353   |
# |    value_loss           | 23.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 750          |
# |    time_elapsed         | 1354         |
# |    total_timesteps      | 768000       |
# | train/                  |              |
# |    approx_kl            | 0.0032751935 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74         |
# |    n_updates            | 2996         |
# |    policy_gradient_loss | -0.000572    |
# |    value_loss           | 9.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 463          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 751          |
# |    time_elapsed         | 1356         |
# |    total_timesteps      | 769024       |
# | train/                  |              |
# |    approx_kl            | 0.0045191348 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.802       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.67         |
# |    n_updates            | 3000         |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 15.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 461          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 752          |
# |    time_elapsed         | 1357         |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0054073706 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.661       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9            |
# |    n_updates            | 3004         |
# |    policy_gradient_loss | -0.00671     |
# |    value_loss           | 22.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 459          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 753          |
# |    time_elapsed         | 1359         |
# |    total_timesteps      | 771072       |
# | train/                  |              |
# |    approx_kl            | 0.0041854046 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.61         |
# |    n_updates            | 3008         |
# |    policy_gradient_loss | -0.00366     |
# |    value_loss           | 17.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 450          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 754          |
# |    time_elapsed         | 1361         |
# |    total_timesteps      | 772096       |
# | train/                  |              |
# |    approx_kl            | 0.0067373947 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.1          |
# |    n_updates            | 3012         |
# |    policy_gradient_loss | -0.000586    |
# |    value_loss           | 9.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | 215          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 755          |
# |    time_elapsed         | 1362         |
# |    total_timesteps      | 773120       |
# | train/                  |              |
# |    approx_kl            | 0.0062159244 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.23         |
# |    n_updates            | 3016         |
# |    policy_gradient_loss | -0.000702    |
# |    value_loss           | 18.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 450          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 756          |
# |    time_elapsed         | 1364         |
# |    total_timesteps      | 774144       |
# | train/                  |              |
# |    approx_kl            | 0.0023350457 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 3020         |
# |    policy_gradient_loss | -0.000912    |
# |    value_loss           | 38.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 448           |
# |    ep_rew_mean          | 213           |
# | time/                   |               |
# |    fps                  | 567           |
# |    iterations           | 757           |
# |    time_elapsed         | 1366          |
# |    total_timesteps      | 775168        |
# | train/                  |               |
# |    approx_kl            | 0.00018945883 |
# |    clip_fraction        | 0.000732      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.78         |
# |    explained_variance   | 0.409         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 790           |
# |    n_updates            | 3024          |
# |    policy_gradient_loss | 0.000454      |
# |    value_loss           | 1.15e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 454          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 758          |
# |    time_elapsed         | 1368         |
# |    total_timesteps      | 776192       |
# | train/                  |              |
# |    approx_kl            | 0.0051171193 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34           |
# |    n_updates            | 3028         |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 71.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 453          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 759          |
# |    time_elapsed         | 1370         |
# |    total_timesteps      | 777216       |
# | train/                  |              |
# |    approx_kl            | 0.0015873337 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.41         |
# |    n_updates            | 3032         |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 8.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 452         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 760         |
# |    time_elapsed         | 1371        |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.003388685 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.69        |
# |    n_updates            | 3036        |
# |    policy_gradient_loss | -0.000757   |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 453         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 761         |
# |    time_elapsed         | 1373        |
# |    total_timesteps      | 779264      |
# | train/                  |             |
# |    approx_kl            | 0.000991885 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 3040        |
# |    policy_gradient_loss | 0.000745    |
# |    value_loss           | 541         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 452         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 762         |
# |    time_elapsed         | 1375        |
# |    total_timesteps      | 780288      |
# | train/                  |             |
# |    approx_kl            | 0.000829667 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 3044        |
# |    policy_gradient_loss | -0.000943   |
# |    value_loss           | 112         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 458          |
# |    ep_rew_mean          | 209          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 763          |
# |    time_elapsed         | 1377         |
# |    total_timesteps      | 781312       |
# | train/                  |              |
# |    approx_kl            | 0.0038282597 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.27         |
# |    n_updates            | 3048         |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 39.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 459         |
# |    ep_rew_mean          | 209         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 764         |
# |    time_elapsed         | 1379        |
# |    total_timesteps      | 782336      |
# | train/                  |             |
# |    approx_kl            | 0.005439155 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.96        |
# |    n_updates            | 3052        |
# |    policy_gradient_loss | -0.000727   |
# |    value_loss           | 15.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 765          |
# |    time_elapsed         | 1380         |
# |    total_timesteps      | 783360       |
# | train/                  |              |
# |    approx_kl            | 0.0046402127 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.1          |
# |    n_updates            | 3056         |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 31.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 464          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 766          |
# |    time_elapsed         | 1382         |
# |    total_timesteps      | 784384       |
# | train/                  |              |
# |    approx_kl            | 0.0029677348 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.79         |
# |    n_updates            | 3060         |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 12.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 463          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 767          |
# |    time_elapsed         | 1384         |
# |    total_timesteps      | 785408       |
# | train/                  |              |
# |    approx_kl            | 0.0012934365 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.5          |
# |    n_updates            | 3064         |
# |    policy_gradient_loss | -1.3e-07     |
# |    value_loss           | 19           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 458          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 768          |
# |    time_elapsed         | 1386         |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0002238017 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.403        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 262          |
# |    n_updates            | 3068         |
# |    policy_gradient_loss | -0.00024     |
# |    value_loss           | 912          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 458          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 769          |
# |    time_elapsed         | 1387         |
# |    total_timesteps      | 787456       |
# | train/                  |              |
# |    approx_kl            | 0.0036587857 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.769       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.61         |
# |    n_updates            | 3072         |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 14.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 457          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 770          |
# |    time_elapsed         | 1389         |
# |    total_timesteps      | 788480       |
# | train/                  |              |
# |    approx_kl            | 0.0011324378 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.722       |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 3076         |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 47           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 771          |
# |    time_elapsed         | 1391         |
# |    total_timesteps      | 789504       |
# | train/                  |              |
# |    approx_kl            | 0.0028775383 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.21         |
# |    n_updates            | 3080         |
# |    policy_gradient_loss | -0.000436    |
# |    value_loss           | 12.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 458          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 772          |
# |    time_elapsed         | 1393         |
# |    total_timesteps      | 790528       |
# | train/                  |              |
# |    approx_kl            | 0.0021070954 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.42         |
# |    n_updates            | 3084         |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 17.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 773         |
# |    time_elapsed         | 1395        |
# |    total_timesteps      | 791552      |
# | train/                  |             |
# |    approx_kl            | 0.008262283 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.18        |
# |    n_updates            | 3088        |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 22          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 455         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 774         |
# |    time_elapsed         | 1396        |
# |    total_timesteps      | 792576      |
# | train/                  |             |
# |    approx_kl            | 0.004685424 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.47        |
# |    n_updates            | 3092        |
# |    policy_gradient_loss | -0.000262   |
# |    value_loss           | 18.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 451         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 775         |
# |    time_elapsed         | 1398        |
# |    total_timesteps      | 793600      |
# | train/                  |             |
# |    approx_kl            | 0.001217511 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 347         |
# |    n_updates            | 3096        |
# |    policy_gradient_loss | 0.00114     |
# |    value_loss           | 865         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 453           |
# |    ep_rew_mean          | 213           |
# | time/                   |               |
# |    fps                  | 567           |
# |    iterations           | 776           |
# |    time_elapsed         | 1400          |
# |    total_timesteps      | 794624        |
# | train/                  |               |
# |    approx_kl            | 0.00020880863 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.804        |
# |    explained_variance   | 0.744         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 93.9          |
# |    n_updates            | 3100          |
# |    policy_gradient_loss | -0.000401     |
# |    value_loss           | 422           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 454           |
# |    ep_rew_mean          | 213           |
# | time/                   |               |
# |    fps                  | 567           |
# |    iterations           | 777           |
# |    time_elapsed         | 1402          |
# |    total_timesteps      | 795648        |
# | train/                  |               |
# |    approx_kl            | 0.00017773017 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.771        |
# |    explained_variance   | 0.839         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 28.7          |
# |    n_updates            | 3104          |
# |    policy_gradient_loss | -0.000354     |
# |    value_loss           | 89.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 456          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 778          |
# |    time_elapsed         | 1404         |
# |    total_timesteps      | 796672       |
# | train/                  |              |
# |    approx_kl            | 0.0053378018 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.69         |
# |    n_updates            | 3108         |
# |    policy_gradient_loss | -0.00352     |
# |    value_loss           | 22.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 779          |
# |    time_elapsed         | 1405         |
# |    total_timesteps      | 797696       |
# | train/                  |              |
# |    approx_kl            | 0.0020215996 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.795       |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.26         |
# |    n_updates            | 3112         |
# |    policy_gradient_loss | -0.000484    |
# |    value_loss           | 29.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 464          |
# |    ep_rew_mean          | 215          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 780          |
# |    time_elapsed         | 1407         |
# |    total_timesteps      | 798720       |
# | train/                  |              |
# |    approx_kl            | 0.0017103148 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.8         |
# |    n_updates            | 3116         |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 26.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 460        |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 567        |
# |    iterations           | 781        |
# |    time_elapsed         | 1409       |
# |    total_timesteps      | 799744     |
# | train/                  |            |
# |    approx_kl            | 0.00668779 |
# |    clip_fraction        | 0.0635     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.819     |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.8       |
# |    n_updates            | 3120       |
# |    policy_gradient_loss | -0.0042    |
# |    value_loss           | 24.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 460          |
# |    ep_rew_mean          | 216          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 782          |
# |    time_elapsed         | 1410         |
# |    total_timesteps      | 800768       |
# | train/                  |              |
# |    approx_kl            | 0.0022831992 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.2          |
# |    n_updates            | 3124         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 21.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 461          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 783          |
# |    time_elapsed         | 1412         |
# |    total_timesteps      | 801792       |
# | train/                  |              |
# |    approx_kl            | 0.0031285277 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.45         |
# |    n_updates            | 3128         |
# |    policy_gradient_loss | -0.000532    |
# |    value_loss           | 9.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 784          |
# |    time_elapsed         | 1414         |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0010006434 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 302          |
# |    n_updates            | 3132         |
# |    policy_gradient_loss | 0.00106      |
# |    value_loss           | 875          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 785         |
# |    time_elapsed         | 1416        |
# |    total_timesteps      | 803840      |
# | train/                  |             |
# |    approx_kl            | 0.004105162 |
# |    clip_fraction        | 0.0083      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.821      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.61        |
# |    n_updates            | 3136        |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 19.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 472          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 786          |
# |    time_elapsed         | 1418         |
# |    total_timesteps      | 804864       |
# | train/                  |              |
# |    approx_kl            | 0.0053987345 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.13         |
# |    n_updates            | 3140         |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 11.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 787         |
# |    time_elapsed         | 1420        |
# |    total_timesteps      | 805888      |
# | train/                  |             |
# |    approx_kl            | 0.007266692 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.85        |
# |    n_updates            | 3144        |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 6.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 473          |
# |    ep_rew_mean          | 215          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 788          |
# |    time_elapsed         | 1421         |
# |    total_timesteps      | 806912       |
# | train/                  |              |
# |    approx_kl            | 0.0025789083 |
# |    clip_fraction        | 0.00732      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.44         |
# |    n_updates            | 3148         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 26.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 472          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 789          |
# |    time_elapsed         | 1423         |
# |    total_timesteps      | 807936       |
# | train/                  |              |
# |    approx_kl            | 0.0047836937 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.719       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25         |
# |    n_updates            | 3152         |
# |    policy_gradient_loss | -0.000596    |
# |    value_loss           | 6.75         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 479          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 790          |
# |    time_elapsed         | 1425         |
# |    total_timesteps      | 808960       |
# | train/                  |              |
# |    approx_kl            | 0.0052873706 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 3156         |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 479         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 791         |
# |    time_elapsed         | 1427        |
# |    total_timesteps      | 809984      |
# | train/                  |             |
# |    approx_kl            | 0.012630232 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32        |
# |    n_updates            | 3160        |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 482         |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 792         |
# |    time_elapsed         | 1429        |
# |    total_timesteps      | 811008      |
# | train/                  |             |
# |    approx_kl            | 0.003647974 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 3164        |
# ...
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0032339632 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.19         |
# |    n_updates            | 3836         |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 22.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | 228          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 961          |
# |    time_elapsed         | 1729         |
# |    total_timesteps      | 984064       |
# | train/                  |              |
# |    approx_kl            | 0.0032652235 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.89         |
# |    n_updates            | 3840         |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 19.2         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 228           |
# | time/                   |               |
# |    fps                  | 569           |
# |    iterations           | 962           |
# |    time_elapsed         | 1731          |
# |    total_timesteps      | 985088        |
# | train/                  |               |
# |    approx_kl            | 0.00078606914 |
# |    clip_fraction        | 0.00244       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.778        |
# |    explained_variance   | 0.471         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 135           |
# |    n_updates            | 3844          |
# |    policy_gradient_loss | 0.000878      |
# |    value_loss           | 1.02e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 333           |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 569           |
# |    iterations           | 963           |
# |    time_elapsed         | 1732          |
# |    total_timesteps      | 986112        |
# | train/                  |               |
# |    approx_kl            | 0.00043469534 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.721        |
# |    explained_variance   | 0.603         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 522           |
# |    n_updates            | 3848          |
# |    policy_gradient_loss | -0.000186     |
# |    value_loss           | 904           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 964         |
# |    time_elapsed         | 1734        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.003965693 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.7        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.02        |
# |    n_updates            | 3852        |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 41          |
# -----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 322            |
# |    ep_rew_mean          | 226            |
# | time/                   |                |
# |    fps                  | 569            |
# |    iterations           | 965            |
# |    time_elapsed         | 1736           |
# |    total_timesteps      | 988160         |
# | train/                  |                |
# |    approx_kl            | 0.000120343175 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.773         |
# |    explained_variance   | 0.538          |
# |    learning_rate        | 0.0003         |
# |    loss                 | 764            |
# |    n_updates            | 3856           |
# |    policy_gradient_loss | 0.000109       |
# |    value_loss           | 1.61e+03       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 966          |
# |    time_elapsed         | 1738         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0005815407 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.702       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 260          |
# |    n_updates            | 3860         |
# |    policy_gradient_loss | -0.00057     |
# |    value_loss           | 130          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 967         |
# |    time_elapsed         | 1740        |
# |    total_timesteps      | 990208      |
# | train/                  |             |
# |    approx_kl            | 0.003796588 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.91        |
# |    n_updates            | 3864        |
# |    policy_gradient_loss | 0.000178    |
# |    value_loss           | 24          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 968         |
# |    time_elapsed         | 1741        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.006129336 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.77        |
# |    n_updates            | 3868        |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 321          |
# |    ep_rew_mean          | 227          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 969          |
# |    time_elapsed         | 1743         |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0008427586 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 3872         |
# |    policy_gradient_loss | -0.000228    |
# |    value_loss           | 706          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 322           |
# |    ep_rew_mean          | 225           |
# | time/                   |               |
# |    fps                  | 569           |
# |    iterations           | 970           |
# |    time_elapsed         | 1745          |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 9.7235374e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.672        |
# |    explained_variance   | 0.594         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 526           |
# |    n_updates            | 3876          |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 939           |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 321            |
# |    ep_rew_mean          | 224            |
# | time/                   |                |
# |    fps                  | 569            |
# |    iterations           | 971            |
# |    time_elapsed         | 1746           |
# |    total_timesteps      | 994304         |
# | train/                  |                |
# |    approx_kl            | 0.000108641514 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.779         |
# |    explained_variance   | 0.58           |
# |    learning_rate        | 0.0003         |
# |    loss                 | 323            |
# |    n_updates            | 3880           |
# |    policy_gradient_loss | -0.000304      |
# |    value_loss           | 853            |
# --------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 319         |
# |    ep_rew_mean          | 222         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 972         |
# |    time_elapsed         | 1748        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.002456805 |
# |    clip_fraction        | 0.00415     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.22        |
# |    n_updates            | 3884        |
# |    policy_gradient_loss | -0.000767   |
# |    value_loss           | 19.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 318          |
# |    ep_rew_mean          | 223          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 973          |
# |    time_elapsed         | 1750         |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0034645624 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0.664        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 680          |
# |    n_updates            | 3888         |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 811          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 974          |
# |    time_elapsed         | 1752         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0033552218 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.71        |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 228          |
# |    n_updates            | 3892         |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 258          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 219          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 975          |
# |    time_elapsed         | 1754         |
# |    total_timesteps      | 998400       |
# | train/                  |              |
# |    approx_kl            | 0.0018691246 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.719       |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 3896         |
# |    policy_gradient_loss | -0.000729    |
# |    value_loss           | 63.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 321          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 976          |
# |    time_elapsed         | 1755         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0010254087 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.68        |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.2         |
# |    n_updates            | 3900         |
# |    policy_gradient_loss | -0.000529    |
# |    value_loss           | 779          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 320           |
# |    ep_rew_mean          | 217           |
# | time/                   |               |
# |    fps                  | 569           |
# |    iterations           | 977           |
# |    time_elapsed         | 1757          |
# |    total_timesteps      | 1000448       |
# | train/                  |               |
# |    approx_kl            | 0.00016360165 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.764        |
# |    explained_variance   | 0.633         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 260           |
# |    n_updates            | 3904          |
# |    policy_gradient_loss | -0.000816     |
# |    value_loss           | 718           |
# -------------------------------------------

# %%
eval_env = Monitor(gym.make('LunarLander-v2'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# mean_reward=224.47 +/- 84.93117355055816

# %%
from stable_baselines3.common.vec_env import DummyVecEnv


# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "Thomas-c-reid/ppo-LunarLander-v2" # Change with your repo id, you can't push with mine 😄

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

token='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'

# PLACE the package_to_hub function you've just filled here
package_to_hub(token=token,
                model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmptbo3nhv7/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmptbo3nhv7/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmptbo3nhv7/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmptbo3nhv7/-step-0-to-step-1000.mp4
# ℹ Pushing repo Thomas-c-reid/ppo-LunarLander-v2 to the Hugging Face
# Hub
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/88.4k [00:00<?, ?B/s]
# policy.pth:   0%|          | 0.00/43.8k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# ppo-LunarLander-v2.zip:   0%|          | 0.00/147k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Thomas-c-reid/ppo-LunarLander-v2/tree/main/
# CommitInfo(commit_url='https://huggingface.co/thomas-c-reid/ppo-LunarLander-v2/commit/d9b6017b8f9acb06469a6598c0bb6bbe2f5e51dd', commit_message='Upload PPO LunarLander-v2 trained agent', commit_description='', oid='d9b6017b8f9acb06469a6598c0bb6bbe2f5e51dd', pr_url=None, pr_revision=None, pr_num=None)
